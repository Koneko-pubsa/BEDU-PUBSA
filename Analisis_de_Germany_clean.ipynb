# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Archivo Ernest :D
keywords = pd.read_csv("/content/drive/MyDrive/Curso Bedu/Germany-Clean_Keywords_20210101-20210630.csv")
#Archivo Frank
#keywords = pd.read_csv("/content/drive/MyDrive/Curso Bedu/Germany-Clean_Keywords_20210101-20210630.csv")

# %%
keywords
# Out:
#          Palabra clave de la Búsqueda  ... CPM prom.
# 0                   lavado de colchón  ...         0
# 1                      lavado de sala  ...  2,302.19
# 2     lavado de alfombras profesional  ...         0
# 3     lavado de alfombras profesional  ...         0
# 4     lavado de alfombras a domicilio  ...         0
# ...                               ...  ...       ...
# 2975     lavado alfombras a domicilio  ...  2,038.00
# 2976              limpieza de tapetes  ...  3,831.61
# 2977         lavado de tapetes persas  ...         0
# 2978              lavado de colchones  ...       415
# 2979    lavado de tapetes a domicilio  ...  8,018.75
#
# [2980 rows x 20 columns]

# %%
df_keywords = pd.DataFrame(keywords)

# %% [markdown]
# desechamos las columnas que no ocupamos  ["Conv. posimpresión", "CPM prom."]

# %%
df_keywords.drop(columns=["Conv. posimpresión", "CPM prom."])
# Out:
#          Palabra clave de la Búsqueda  ... Porcentaje de conv.
# 0                   lavado de colchón  ...              0.00 %
# 1                      lavado de sala  ...             33.33 %
# 2     lavado de alfombras profesional  ...              0.00 %
# 3     lavado de alfombras profesional  ...              0.00 %
# 4     lavado de alfombras a domicilio  ...              0.00 %
# ...                               ...  ...                 ...
# 2975     lavado alfombras a domicilio  ...              0.00 %
# 2976              limpieza de tapetes  ...              0.00 %
# 2977         lavado de tapetes persas  ...              0.00 %
# 2978              lavado de colchones  ...              0.00 %
# 2979    lavado de tapetes a domicilio  ...              0.00 %
#
# [2980 rows x 18 columns]

# %% [markdown]
# Renombramos las columnas

# %% [markdown]
# #Nombres de columnas
# keywords |
# match |
# campaign |
# ad_groups |
# cpc_max |
# currency |
# day |
# date |
# clicks |
# impressions |
# ctr |
# cpc_avg |
# cost |
# top_abs_percent |
# top_percent |
# conversions |
# conv_post_impression (delete) |
# cpl |
# conv_percent |
# cpm_prom (delete)

# %%
df_keywords.columns = ['keyword','match', 'campaign', 'ad_groups', 'cpc_max', 'currency', 'day', 'date', 'clicks', 'impressions', 'ctr', 'cpc_avg',
       'cost', 'top_abs_percent', 'top_percent', 'conversions', 'conv_post_impression', 'cpl',
       'conv_percent', 'cpm_prom']
df_keywords.columns
# Out:
# Index(['keyword', 'match', 'campaign', 'ad_groups', 'cpc_max', 'currency',
#        'day', 'date', 'clicks', 'impressions', 'ctr', 'cpc_avg', 'cost',
#        'top_abs_percent', 'top_percent', 'conversions', 'conv_post_impression',
#        'cpl', 'conv_percent', 'cpm_prom'],
#       dtype='object')

# %%
df_keywords.head()
# Out:
#                            keyword   match  ... conv_percent  cpm_prom
# 0                lavado de colchón  Amplia  ...       0.00 %         0
# 1                   lavado de sala  Amplia  ...      33.33 %  2,302.19
# 2  lavado de alfombras profesional  Amplia  ...       0.00 %         0
# 3  lavado de alfombras profesional  Amplia  ...       0.00 %         0
# 4  lavado de alfombras a domicilio  Amplia  ...       0.00 %         0
#
# [5 rows x 20 columns]

# %%
df_keywords
# Out:
#                               keyword   match  ... conv_percent  cpm_prom
# 0                   lavado de colchón  Amplia  ...       0.00 %         0
# 1                      lavado de sala  Amplia  ...      33.33 %  2,302.19
# 2     lavado de alfombras profesional  Amplia  ...       0.00 %         0
# 3     lavado de alfombras profesional  Amplia  ...       0.00 %         0
# 4     lavado de alfombras a domicilio  Amplia  ...       0.00 %         0
# ...                               ...     ...  ...          ...       ...
# 2975     lavado alfombras a domicilio  Amplia  ...       0.00 %  2,038.00
# 2976              limpieza de tapetes  Amplia  ...       0.00 %  3,831.61
# 2977         lavado de tapetes persas  Amplia  ...       0.00 %         0
# 2978              lavado de colchones  Amplia  ...       0.00 %       415
# 2979    lavado de tapetes a domicilio  Amplia  ...       0.00 %  8,018.75
#
# [2980 rows x 20 columns]

# %%
df_keywords.isna()
# Out:
#       keyword  match  campaign  ...    cpl  conv_percent  cpm_prom
# 0       False  False     False  ...  False         False     False
# 1       False  False     False  ...  False         False     False
# 2       False  False     False  ...  False         False     False
# 3       False  False     False  ...  False         False     False
# 4       False  False     False  ...  False         False     False
# ...       ...    ...       ...  ...    ...           ...       ...
# 2975    False  False     False  ...  False         False     False
# 2976    False  False     False  ...  False         False     False
# 2977    False  False     False  ...  False         False     False
# 2978    False  False     False  ...  False         False     False
# 2979    False  False     False  ...  False         False     False
#
# [2980 rows x 20 columns]

# %%
df_keywords.isna().sum(axis=0)
# Out:
# keyword                 0
# match                   0
# campaign                0
# ad_groups               0
# cpc_max                 0
# currency                0
# day                     0
# date                    0
# clicks                  0
# impressions             0
# ctr                     0
# cpc_avg                 0
# cost                    0
# top_abs_percent         0
# top_percent             0
# conversions             0
# conv_post_impression    0
# cpl                     0
# conv_percent            0
# cpm_prom                0
# dtype: int64

# %%
df_keywords.isna().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2975    0
# 2976    0
# 2977    0
# 2978    0
# 2979    0
# Length: 2980, dtype: int64

# %%
df_keywords.dtypes
# Out:
# keyword                  object
# match                    object
# campaign                 object
# ad_groups                object
# cpc_max                   int64
# currency                 object
# day                      object
# date                     object
# clicks                    int64
# impressions               int64
# ctr                      object
# cpc_avg                 float64
# cost                    float64
# top_abs_percent          object
# top_percent              object
# conversions             float64
# conv_post_impression      int64
# cpl                     float64
# conv_percent             object
# cpm_prom                 object
# dtype: object

# %%
df_keywords['date'] = pd.to_datetime(df_keywords['date'], dayfirst=True)

df_keywords.dtypes
# Out:
# keyword                         object
# match                           object
# campaign                        object
# ad_groups                       object
# cpc_max                          int64
# currency                        object
# day                             object
# date                    datetime64[ns]
# clicks                           int64
# impressions                      int64
# ctr                             object
# cpc_avg                        float64
# cost                           float64
# top_abs_percent                 object
# top_percent                     object
# conversions                    float64
# conv_post_impression             int64
# cpl                            float64
# conv_percent                    object
# cpm_prom                        object
# dtype: object

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('white')

# %%
sns.boxplot(df_keywords['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#EL método Describe nos devuelve, cantidad de valores, promedio, desviación estándar, valor mínimo, valor máximo y cuartiles 25%, 50% y 75%
df_keywords['cpc_avg'].describe()
# Out:
# count    2980.000000
# mean       15.033470
# std        11.515071
# min         0.000000
# 25%         0.000000
# 50%        16.045000
# 75%        22.690000
# max        74.440000
# Name: cpc_avg, dtype: float64

# %%
#Comportamiento del costo por clic (CPC) durante el periodo
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(60,8)})

key = sns.boxplot(data=df_keywords.sort_values(by='date',ascending=True), x='date', y='cpc_avg');
key.set_xticklabels(key.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
keywords_non_0 = keywords[keywords.cpc_avg != 0]

keywords_non_0 = keywords_non_0.sort_values(by='date',ascending=True)

# %%
keywords_non_0
# Out:
#                                 keyword   match  ... conv_percent  cpm_prom
# 2377  limpieza de colchones a domicilio  Amplia  ...       0.00 %  3,744.00
# 1636    lavado de alfombras profesional  Amplia  ...       0.00 %  3,030.00
# 378         lavado de salas a domicilio  Amplia  ...       0.00 %    165.71
# 2901                  limpieza de salas  Amplia  ...       0.00 %  2,456.15
# 2978                lavado de colchones  Amplia  ...       0.00 %       415
# ...                                 ...     ...  ...          ...       ...
# 2861                 limpieza alfombras  Amplia  ...      18.18 %  3,282.32
# 2557        lavado de salas a domicilio  Amplia  ...      12.50 %  1,956.30
# 802                   limpieza de sofas  Amplia  ...      33.33 %  2,962.92
# 2350                limpieza de tapetes  Amplia  ...       0.00 %  4,352.38
# 1486       lavado alfombras a domicilio  Amplia  ...      16.67 %  4,514.33
#
# [2230 rows x 20 columns]

# %%
#Ahora trabajamos el DF sin los valores en 0, el método Describe nos devuelve, cantidad de valores, promedio, desviación estándar, valor mínimo, valor máximo y cuartiles 25%, 50% y 75%
keywords_non_0['cpc_avg'].describe()
# Out:
# count    2230.000000
# mean       20.089570
# std         8.694353
# min         0.260000
# 25%        14.322500
# 50%        19.345000
# 75%        24.887500
# max        74.440000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_non_0['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Comportamiento diario del CPC

sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_non_0.sort_values(by='date',ascending=True), x='date', y='cpc_avg');
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
#Cantidad de grupos de anuncios
keywords_non_0['ad_groups'].unique()
# Out:
# array(['Lavado Colchones', 'Lavado de Alfombras', 'Lavado de Salas',
#        'Lavado de Tapetes', 'Germany Clean Brand'], dtype=object)

# %%
#Separar por grupos de anuncios
keywords_Lavado_de_Salas = keywords_non_0[keywords_non_0.ad_groups == "Lavado de Salas"]
keywords_Lavado_de_Tapetes = keywords_non_0[keywords_non_0.ad_groups == "Lavado de Tapetes"]
keywords_Lavado_Colchones = keywords_non_0[keywords_non_0.ad_groups == "Lavado Colchones"]
keywords_Lavado_de_Alfombras = keywords_non_0[keywords_non_0.ad_groups == "Lavado de Alfombras"]
keywords_Germany_Clean_Brand = keywords_non_0[keywords_non_0.ad_groups == "Germany Clean Brand"]

# %%
#Ordenar los DF
keywords_Lavado_de_Salas = keywords_Lavado_de_Salas.sort_values(by='date',ascending=True)
keywords_Lavado_de_Tapetes = keywords_Lavado_de_Tapetes.sort_values(by='date',ascending=True)
keywords_Lavado_Colchones = keywords_Lavado_Colchones.sort_values(by='date',ascending=True)
keywords_Lavado_de_Alfombras = keywords_Lavado_de_Alfombras.sort_values(by='date',ascending=True)
keywords_Germany_Clean_Brand = keywords_Germany_Clean_Brand.sort_values(by='date',ascending=True)

# %%
#Analisis de cada grupo de anuncios
keywords_Lavado_de_Salas['cpc_avg'].describe()
# Out:
# count    737.000000
# mean      19.672619
# std        7.737799
# min        0.870000
# 25%       14.610000
# 50%       18.770000
# 75%       23.660000
# max       54.340000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_Lavado_de_Salas['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_Lavado_de_Salas.sort_values(by='date',ascending=True), x='date', y='cpc_avg');
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
keywords_Lavado_de_Tapetes['cpc_avg'].describe()
# Out:
# count    392.000000
# mean      22.516020
# std        9.858974
# min        0.390000
# 25%       15.615000
# 50%       21.940000
# 75%       27.785000
# max       63.250000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_Lavado_de_Tapetes['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_Lavado_de_Tapetes.sort_values(by='date',ascending=True), x='date', y='cpc_avg')
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
keywords_Lavado_Colchones['cpc_avg'].describe()
# Out:
# count    615.000000
# mean      19.178325
# std        8.698928
# min        0.580000
# 25%       13.445000
# 50%       18.260000
# 75%       23.520000
# max       74.440000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_Lavado_Colchones['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_Lavado_Colchones.sort_values(by='date',ascending=True), x='date', y='cpc_avg')
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
keywords_Lavado_de_Alfombras['cpc_avg'].describe()
# Out:
# count    455.000000
# mean      20.205429
# std        8.272681
# min        1.280000
# 25%       14.560000
# 50%       20.090000
# 75%       24.980000
# max       59.780000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_Lavado_de_Alfombras['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_Lavado_de_Alfombras.sort_values(by='date',ascending=True), x='date', y='cpc_avg')
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-01-01T00:00:00.000000000'),
#  Text(0, 0, '2021-01-02T00:00:00.000000000'),
#  Text(0, 0, '2021-01-03T00:00:00.000000000'),
#  Text(0, 0, '2021-01-04T00:00:00.000000000'),
#  Text(0, 0, '2021-01-05T00:00:00.000000000'),
#  Text(0, 0, '2021-01-06T00:00:00.000000000'),
#  Text(0, 0, '2021-01-07T00:00:00.000000000'),
#  Text(0, 0, '2021-01-08T00:00:00.000000000'),
#  Text(0, 0, '2021-01-09T00:00:00.000000000'),
#  Text(0, 0, '2021-01-10T00:00:00.000000000'),
#  Text(0, 0, '2021-01-11T00:00:00.000000000'),
#  Text(0, 0, '2021-01-12T00:00:00.000000000'),
#  Text(0, 0, '2021-01-13T00:00:00.000000000'),
#  Text(0, 0, '2021-01-14T00:00:00.000000000'),
#  Text(0, 0, '2021-01-15T00:00:00.000000000'),
#  Text(0, 0, '2021-01-16T00:00:00.000000000'),
#  Text(0, 0, '2021-01-17T00:00:00.000000000'),
#  Text(0, 0, '2021-01-18T00:00:00.000000000'),
#  Text(0, 0, '2021-01-19T00:00:00.000000000'),
#  Text(0, 0, '2021-01-20T00:00:00.000000000'),
# ...

# %%
keywords_Germany_Clean_Brand['cpc_avg'].describe()
# Out:
# count    31.000000
# mean     15.696774
# std      13.339666
# min       0.260000
# 25%       4.440000
# 50%      12.460000
# 75%      22.995000
# max      52.650000
# Name: cpc_avg, dtype: float64

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.boxplot(keywords_Germany_Clean_Brand['cpc_avg'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc={'figure.figsize':(60,8)})

bp = sns.boxplot(data=keywords_Germany_Clean_Brand.sort_values(by='date',ascending=True), x='date', y='cpc_avg')
bp.set_xticklabels(bp.get_xticklabels(),rotation = 45, size = 10)
# Out:
# [Text(0, 0, '2021-03-12T00:00:00.000000000'),
#  Text(0, 0, '2021-03-13T00:00:00.000000000'),
#  Text(0, 0, '2021-03-18T00:00:00.000000000'),
#  Text(0, 0, '2021-03-19T00:00:00.000000000'),
#  Text(0, 0, '2021-03-22T00:00:00.000000000'),
#  Text(0, 0, '2021-03-25T00:00:00.000000000'),
#  Text(0, 0, '2021-03-26T00:00:00.000000000'),
#  Text(0, 0, '2021-03-27T00:00:00.000000000'),
#  Text(0, 0, '2021-03-29T00:00:00.000000000'),
#  Text(0, 0, '2021-04-01T00:00:00.000000000'),
#  Text(0, 0, '2021-04-08T00:00:00.000000000'),
#  Text(0, 0, '2021-04-09T00:00:00.000000000'),
#  Text(0, 0, '2021-04-17T00:00:00.000000000'),
#  Text(0, 0, '2021-04-23T00:00:00.000000000'),
#  Text(0, 0, '2021-04-27T00:00:00.000000000'),
#  Text(0, 0, '2021-04-28T00:00:00.000000000'),
#  Text(0, 0, '2021-04-29T00:00:00.000000000'),
#  Text(0, 0, '2021-04-30T00:00:00.000000000'),
#  Text(0, 0, '2021-05-03T00:00:00.000000000'),
#  Text(0, 0, '2021-05-04T00:00:00.000000000'),
# ...

# %%
#Obtenemos los valores por arriba del percentil 75 (valores muy caros fuera del promedio)  [repetir para cada grupo]
keywords_Lavado_de_Salas_high = keywords_Lavado_de_Salas[keywords_Lavado_de_Salas.cpc_avg > np.percentile(keywords_Lavado_de_Salas.cpc_avg, 75)]

# %%
keywords_Lavado_de_Salas_high
# Out:
#                                keyword   match  ... conv_percent   cpm_prom
# 2827  lavado de salas a domicilio cdmx  Amplia  ...      50.00 %  25,320.00
# 435        lavado profesional de salas  Amplia  ...     100.00 %   1,638.00
# 1761                   lava salas cdmx  Amplia  ...       0.00 %  14,110.00
# 1475                 limpieza de salas  Amplia  ...       0.00 %   2,011.25
# 1039                 limpieza de salas  Amplia  ...      20.00 %   7,630.59
# ...                                ...     ...  ...          ...        ...
# 2774                   lavado de salas  Amplia  ...      25.00 %   3,812.58
# 2929       lavado de salas a domicilio  Amplia  ...      33.33 %   9,466.96
# 1273                 limpieza de salas  Amplia  ...      87.50 %   6,193.53
# 2674                 limpieza de sofas  Amplia  ...       0.00 %   1,228.64
# 802                  limpieza de sofas  Amplia  ...      33.33 %   2,962.92
#
# [184 rows x 20 columns]

# %%
keywords_Lavado_de_Salas_high.tail(50)
# Out:
#                           keyword   match  ... conv_percent  cpm_prom
# 1099           lavadores de salas  Amplia  ...      16.67 %  7,587.74
# 2763              lavado de salas  Amplia  ...      66.67 %  4,914.00
# 1440           lavadores de salas  Amplia  ...      36.36 %  6,775.32
# 2384            limpieza de salas  Amplia  ...       0.00 %  3,583.94
# 871               lavado de salas  Amplia  ...      44.44 %  5,448.27
# 714             limpieza de salas  Amplia  ...      20.00 %  2,947.45
# 2863              lavado de salas  Amplia  ...      50.00 %  3,413.58
# 1385            limpieza de sofas  Amplia  ...      22.22 %  6,795.23
# 2743           lavadores de salas  Amplia  ...       0.00 %  4,502.97
# 2454           lavadores de salas  Amplia  ...       0.00 %  3,418.33
# 1562            limpieza de salas  Amplia  ...       0.00 %  4,821.79
# 689             limpieza de salas  Amplia  ...      20.00 %  3,134.08
# ...

# %%
keywords_Lavado_de_Salas_high['cpc_avg'].describe()
# Out:
# count    184.000000
# mean      30.157554
# std        5.378148
# min       23.700000
# 25%       25.932500
# 50%       28.695000
# 75%       32.852500
# max       54.340000
# Name: cpc_avg, dtype: float64

# %%
#Analizamos la columna conversiones y solo tenemos 7 como máximo, pero los percentiles se encuentran por debajo
# de un 1.25 conversiones, todos esos valores no nos estan dejando una cantidad buena de conversiones.
keywords_Lavado_de_Salas_high['conversions'].describe()
# Out:
# count    184.000000
# mean       1.034239
# std        1.228652
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.125000
# max        7.000000
# Name: conversions, dtype: float64

# %%
#y se han invertido 23,125.07
keywords_Lavado_de_Salas_high['cost'].sum()
# Out:
# 23125.07

# %%
#para obteber 190 conversiones, nos da un CPA de 121 
keywords_Lavado_de_Salas_high['conversions'].sum()
# Out:
# 190.3

# %%
#CPA 
keywords_Lavado_de_Salas_high['cost'].sum() / keywords_Lavado_de_Salas_high['conversions'].sum()
# Out:
# 121.5190225959012

# %%
keywords_Lavado_de_Salas_promedio = keywords_Lavado_de_Salas[keywords_Lavado_de_Salas.cpc_avg < np.percentile(keywords_Lavado_de_Salas.cpc_avg, 75)]

# %%
keywords_Lavado_de_Salas_promedio
# Out:
#                           keyword   match  ... conv_percent  cpm_prom
# 378   lavado de salas a domicilio  Amplia  ...       0.00 %    165.71
# 2901            limpieza de salas  Amplia  ...       0.00 %  2,456.15
# 1435              lavado de salas  Amplia  ...       0.00 %       874
# 1054           lavado de sillones  Amplia  ...       0.00 %  1,800.67
# 837   lavado de salas a domicilio  Amplia  ...       0.00 %  1,465.88
# ...                           ...     ...  ...          ...       ...
# 2746               lavado de sala  Amplia  ...      16.67 %  5,553.91
# 1570              lavado de salas  Amplia  ...      12.50 %  2,526.67
# 2557  lavado de salas a domicilio  Amplia  ...      12.50 %  1,956.30
# 2973               lavado de sala  Amplia  ...       0.00 %  1,003.61
# 1251            limpieza de salas  Amplia  ...       0.00 %  1,199.58
#
# [552 rows x 20 columns]

# %%
keywords_Lavado_de_Salas_promedio = keywords_Lavado_de_Salas_promedio[keywords_Lavado_de_Salas_promedio.cpc_avg > np.percentile(keywords_Lavado_de_Salas.cpc_avg, 25)]

# %%
keywords_Lavado_de_Salas_promedio
# Out:
#                           keyword   match  ... conv_percent  cpm_prom
# 2332            limpieza de salas  Amplia  ...      66.67 %  2,000.30
# 126               lavado de salas  Amplia  ...      20.00 %  4,102.73
# 718               lavado de salas  Amplia  ...      50.00 %  3,720.53
# 1168  lavado de salas a domicilio  Amplia  ...     100.00 %  1,284.17
# 2076           lavado de sillones  Amplia  ...       0.00 %  2,559.33
# ...                           ...     ...  ...          ...       ...
# 1159            limpieza de sofas  Amplia  ...      25.00 %  4,571.71
# 2474               lavado de sala  Amplia  ...     100.00 %  1,407.50
# 1835            limpieza de sofas  Amplia  ...      50.00 %  1,757.89
# 1894              lavado de salas  Amplia  ...      50.00 %  1,792.44
# 2746               lavado de sala  Amplia  ...      16.67 %  5,553.91
#
# [367 rows x 20 columns]

# %%
# Costo o inversión
keywords_Lavado_de_Salas_promedio['cost'].sum()
# Out:
# 28846.72

# %%
#Conversiones o clientes potenciales
keywords_Lavado_de_Salas_promedio['conversions'].sum()
# Out:
# 314.93

# %%
#CPA Costo por adquisición 
keywords_Lavado_de_Salas_promedio['cost'].sum() / keywords_Lavado_de_Salas_promedio['conversions'].sum()
# Out:
# 91.59724383196266

# %%
########################################################################
########################################################################
########################################################################
########################################################################

# %%
x = keywords_Lavado_de_Salas.date
y = keywords_Lavado_de_Salas.cpc_avg



plt.plot(x,y,marker="o")
plt.gcf().set_size_inches(60, 7)
plt.show()

# %%
sns.set(rc={'figure.figsize':(8,8)})

disp_keyw = sns.scatterplot(keywords_non_0['date'], keywords_non_0['cpc_avg'])
disp_keyw.set_xticklabels(disp_keyw.get_xticklabels(),rotation = 45, size = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
scat_campaign = sns.scatterplot(keywords_non_0['date'], keywords_non_0['cpc_avg'], hue=keywords_non_0['ad_groups']);

scat_campaign.set_xticklabels(scat_campaign.get_xticklabels(),rotation = 45, size = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
#Ultimos 7 días
group_by_date = keywords_non_0.groupby(['date','campaign','ad_groups'])['cpc_avg'].mean().reset_index()

group_by_date = group_by_date.sort_values(by='date',ascending=True)

last_15 = group_by_date.tail(50)

last_15
# Out:
#           date                    campaign            ad_groups    cpc_avg
# 591 2021-06-16  SRC_PRF_Germany_Clean_CDMX  Lavado de Alfombras  20.770000
# 592 2021-06-16  SRC_PRF_Germany_Clean_CDMX      Lavado de Salas  19.596667
# 596 2021-06-17  SRC_PRF_Germany_Clean_CDMX      Lavado de Salas  27.286667
# 597 2021-06-17  SRC_PRF_Germany_Clean_CDMX    Lavado de Tapetes  26.855000
# 594 2021-06-17  SRC_PRF_Germany_Clean_CDMX     Lavado Colchones  17.205000
# 595 2021-06-17  SRC_PRF_Germany_Clean_CDMX  Lavado de Alfombras  23.105000
# 598 2021-06-18  SRC_PRF_Germany_Clean_CDMX     Lavado Colchones  20.367500
# 599 2021-06-18  SRC_PRF_Germany_Clean_CDMX  Lavado de Alfombras  23.520000
# 600 2021-06-18  SRC_PRF_Germany_Clean_CDMX      Lavado de Salas  26.358000
# 601 2021-06-18  SRC_PRF_Germany_Clean_CDMX    Lavado de Tapetes  25.325000
# 604 2021-06-19  SRC_PRF_Germany_Clean_CDMX      Lavado de Salas  18.884000
# ...

# %%
#Dispersion últimos 50

import numpy as np;

sns.set(rc={'figure.figsize':(8,8)})

disp_15 = sns.scatterplot(last_15['date'], last_15['cpc_avg'])
disp_15.set_xticklabels(disp_15.get_xticklabels(),rotation = 45, size = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
keywords = pd.read_csv("/content/drive/MyDrive/Proyecto/Germany-Clean_Keywords_20210101-20210630.csv")
keywords
# Out:
#          Palabra clave de la Búsqueda  ... CPM prom.
# 0                   lavado de colchón  ...         0
# 1                      lavado de sala  ...  2,302.19
# 2     lavado de alfombras profesional  ...         0
# 3     lavado de alfombras profesional  ...         0
# 4     lavado de alfombras a domicilio  ...         0
# ...                               ...  ...       ...
# 2975     lavado alfombras a domicilio  ...  2,038.00
# 2976              limpieza de tapetes  ...  3,831.61
# 2977         lavado de tapetes persas  ...         0
# 2978              lavado de colchones  ...       415
# 2979    lavado de tapetes a domicilio  ...  8,018.75
#
# [2980 rows x 20 columns]

# %%
keywords.isna().sum()
# Out:
# Palabra clave de la Búsqueda                     0
# Buscar tipo de concordancia de palabras clave    0
# Campaña                                          0
# Grupo de anuncios                                0
# CPC máximo de palabras clave                     0
# Moneda                                           0
# Día de la semana                                 0
# Día                                              0
# Clics                                            0
# Impresiones                                      0
# CTR                                              0
# CPC prom.                                        0
# Costo                                            0
# % impr. (parte sup. abs.)                        0
# % impr. (parte sup.)                             0
# Conversiones                                     0
# Conv. posimpresión                               0
# Costo/conv.                                      0
# ...

# %%
keywords = keywords.drop(columns=['Conv. posimpresión'])

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(keywords.corr(), annot=True);
